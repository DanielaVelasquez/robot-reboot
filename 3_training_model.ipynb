# %%
import boto3
import sagemaker

# %%
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

bucket = sagemaker_session.default_bucket()

# %%
bucket
# Out:
# 'sagemaker-us-east-1-322961843176'

# %% [markdown]
# ### Upload training data to S3

# %%
data_dir = 'robot_reboot_data'
prefix = 'sagemaker/robot_reboot'
input_data = sagemaker_session.upload_data(path=data_dir, bucket=bucket, key_prefix=prefix)

# %%
sagemaker_session.upload_data(path='robot_reboot_model', bucket=bucket, key_prefix=prefix)
# Out:
# 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot'

# %%
for obj in boto3.resource('s3').Bucket(bucket).objects.all():
    print(obj.key)
# Out:
# robot_reboot-2021-03-27-00-01-00-089/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-02-05-167/model.tar.gz
# robot_reboot-2021-03-27-00-02-05-167/output.tar.gz
# robot_reboot-2021-03-27-00-02-05-167/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-05-07-280/model.tar.gz
# robot_reboot-2021-03-27-00-05-07-280/output.tar.gz
# robot_reboot-2021-03-27-00-05-07-280/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-06-50-289/model.tar.gz
# robot_reboot-2021-03-27-00-06-50-289/output.tar.gz
# robot_reboot-2021-03-27-00-06-50-289/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-09-37-901/model.tar.gz
# robot_reboot-2021-03-27-00-09-37-901/output.tar.gz
# robot_reboot-2021-03-27-00-09-37-901/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-16-25-899/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-17-07-630/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-17-23-327/model.tar.gz
# robot_reboot-2021-03-27-00-17-23-327/output.tar.gz
# robot_reboot-2021-03-27-00-17-23-327/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-19-21-200/model.tar.gz
# robot_reboot-2021-03-27-00-19-21-200/output.tar.gz
# robot_reboot-2021-03-27-00-19-21-200/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-24-30-910/model.tar.gz
# robot_reboot-2021-03-27-00-24-30-910/output.tar.gz
# robot_reboot-2021-03-27-00-24-30-910/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-43-28-948/model.tar.gz
# robot_reboot-2021-03-27-00-43-28-948/output.tar.gz
# robot_reboot-2021-03-27-00-43-28-948/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-44-39-050/model.tar.gz
# robot_reboot-2021-03-27-00-44-39-050/output.tar.gz
# robot_reboot-2021-03-27-00-44-39-050/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-45-40-888/model.tar.gz
# robot_reboot-2021-03-27-00-45-40-888/output.tar.gz
# robot_reboot-2021-03-27-00-45-40-888/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-46-29-473/model.tar.gz
# robot_reboot-2021-03-27-00-46-29-473/output.tar.gz
# robot_reboot-2021-03-27-00-46-29-473/source/sourcedir.tar.gz
# robot_reboot-2021-03-27-00-47-18-630/model.tar.gz
# robot_reboot-2021-03-27-00-47-18-630/output.tar.gz
# robot_reboot-2021-03-27-00-47-18-630/source/sourcedir.tar.gz
# sagemaker/robot_reboot/model_0/.data-00000-of-00001
# sagemaker/robot_reboot/model_0/.index
# sagemaker/robot_reboot/model_0/checkpoint
# sagemaker/robot_reboot/train.tfrecords
# sagemaker/robot_reboot/validation.tfrecords

# %%
# !pygmentize src/ml/train.py
# Out:
# import argparse
# import logging
# import os
#
# import tensorflow as tf
# from tensorflow.keras.callbacks import ModelCheckpoint
# from model import get_model
#
# logging.getLogger().setLevel(logging.INFO)
#
# HEIGHT = 31
# WIDTH = 31
# DEPTH = 9
# NUM_CLASSES = 16
# SHUFFLE_BUFFER_SIZE = 100
#
#
# def get_filenames(channel_name, channel):
#     if channel_name in ['train', 'validation', 'eval']:
#         return [os.path.join(channel, f'{channel_name}.tfrecords')]
#     else:
#         raise ValueError(f'Invalid data for {channel_name}')
#
#
# def read_tfrecord(example):
#     feature_desc = {
#         'v': tf.io.FixedLenFeature([], tf.float32),
#         'p': tf.io.VarLenFeature(tf.float32),
#         's': tf.io.VarLenFeature(tf.float32)
#     }
#     parsed = tf.io.parse_single_example(example, feature_desc)
#     x = tf.reshape(tf.sparse.to_dense(parsed['s']), (1, HEIGHT, WIDTH, DEPTH))
#     p = tf.reshape(tf.sparse.to_dense(parsed['p']), (1, 16))
#     v = tf.reshape(parsed['v'], (1, 1))
#
#     y = {'v': v, 'p': p}
#     return x, y
#
#
# def _input(epochs, channel, channel_name):
#     filenames = get_filenames(channel_name, channel)
#     dataset = tf.data.TFRecordDataset(filenames)
#     dataset = dataset.map(read_tfrecord)  # , num_parallel_calls=20)
#
#     # if channel_name == 'train':
#     #     dataset = dataset.repeat(epochs)
#     #     dataset = dataset.shuffle(SHUFFLE_BUFFER_SIZE).prefetch(1)
#
#     return dataset
#
#
# def save_model(model, dir, version):
#     output = os.path.join(dir, 'model_' + version)
#     model.save(output)
#
#     logging.info("Model successfully saved at: {}".format(output))
#
#
# def train(args):
#     logging.info("Getting data sets")
#     train_ds = _input(args.epochs, args.train, 'train')
#     valid_ds = _input(args.epochs, args.validation, 'validation')
#     eval_ds = _input(args.epochs, args.eval, 'eval')
#
#     logging.info("Loading model")
#     model = get_model((31, 31, 9), n_outputs=16, convolutions=3, optimizer='adam', seed=26)
#     model.load_weights(args.model)
#     losses = {
#         "v": 'mean_squared_error',
#         "p": tf.keras.losses.BinaryCrossentropy()
#     }
#     model.compile(loss=losses, optimizer='adam')
#
#     checkpoint = ModelCheckpoint(args.model_dir + 'checkpoint_{epoch}.h5')
#
#     logging.info("Starting to train")
#     model.fit(train_ds)  # , epochs=args.epochs, validation_data=valid_ds, callbacks=[checkpoint])
#     #
#     # logging.info("Evaluating the model")
#     # v_eval, p_eval = model.evaluate(eval_ds)
#     #
#     # logging.info('Test loss v:{}'.format(v_eval))
#     # logging.info('Tess loss p:{}'.format(p_eval))
#
#     return save_model(model, args.model_dir, args.model_version)
#
#
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#     parser.add_argument(
#         '--train',
#         type=str,
#         required=True,
#         help='Directory where the robot reboot training data is stored'
#     )
#     parser.add_argument(
#         '--validation',
#         type=str,
#         required=True,
#         help='Directory where the robot reboot validation data is stored'
#     )
#     parser.add_argument(
#         '--eval',
#         type=str,
#         required=True,
#         help='Directory where the robot reboot evaluation data is stored'
#     )
#     parser.add_argument(
#         '--model',
#         type=str,
#         required=True,
#         help='Directory where the current model is stored'
#     )
#     parser.add_argument(
#         '--model_dir',
#         type=str,
#         required=True,
#         help='Directory where the model will be stored'
#     )
#     parser.add_argument(
#         '--model_version',
#         type=str,
#         required=True,
#         help='Directory where the model will be stored'
#     )
#     parser.add_argument(
#         '--epochs',
#         type=int,
#         default=10,
#         help='The number of steps to use for training.'
#     )
#     args = parser.parse_args()
#     train(args)

# %% [markdown]
# ### Create estimator

# %%
# !pip install --upgrade sagemaker
# Out:
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (2.31.0)
# Collecting sagemaker
#   Downloading sagemaker-2.32.0.tar.gz (405 kB)
#      |████████████████████████████████| 405 kB 17.3 MB/s eta 0:00:01
# Requirement already satisfied: attrs in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (20.3.0)
# Requirement already satisfied: boto3>=1.16.32 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (1.17.34)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (1.18.5)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (3.15.2)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: smdebug_rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (3.7.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (20.9)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (1.1.5)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.3.4)
# Requirement already satisfied: botocore<1.21.0,>=1.20.34 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (1.20.34)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.34->boto3>=1.16.32->sagemaker) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.34->boto3>=1.16.32->sagemaker) (1.26.3)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from packaging>=20.0->sagemaker) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker) (1.15.0)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from pandas->sagemaker) (2021.1)
# Building wheels for collected packages: sagemaker
#   Building wheel for sagemaker (setup.py) ... done
#   Created wheel for sagemaker: filename=sagemaker-2.32.0-py2.py3-none-any.whl size=570899 sha256=1b9eceab0b0ea5756527f6e9515d545846cd77b07da818371dde766ccedd6e77
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/69/97/97/3cc021580a00f6ec531125f88d49baf9ec4385afabe45ecf11
# Successfully built sagemaker
# Installing collected packages: sagemaker
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.31.0
#     Uninstalling sagemaker-2.31.0:
#       Successfully uninstalled sagemaker-2.31.0
# Successfully installed sagemaker-2.32.0

# %%
from sagemaker.tensorflow import TensorFlow
estimator = TensorFlow(base_job_name='robot_reboot',
                      entry_point='train.py',
                      source_dir='src/ml',
                      role=role,
                      framework_version="2.2.0",
                      py_version='py37',
                      hyperparameters={
                          'epochs': 1,
                          'model': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/',
                          'train': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/train.tfrecords',
                          'validation': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords',
                          'eval': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords',
                          'model_version': 1
                      },
                      train_instance_count=1, 
                      train_instance_type='local')
# Out:
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
estimator.fit({'train': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/train.tfrecords',
              'validation': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords',
              'eval': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords'})
# Out:
# Creating 47km6iougl-algo-1-gedv4 ...
# Creating 47km6iougl-algo-1-gedv4 ... done
# Attaching to 47km6iougl-algo-1-gedv4
# 47km6iougl-algo-1-gedv4 | 2021-03-29 23:00:45.615074: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:425] Initializing the SageMaker Profiler.
# 47km6iougl-algo-1-gedv4 | 2021-03-29 23:00:45.615243: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:106] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 47km6iougl-algo-1-gedv4 | 2021-03-29 23:00:45.638367: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:425] Initializing the SageMaker Profiler.
# 47km6iougl-algo-1-gedv4 | 2021-03-29 23:00:47,611 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 47km6iougl-algo-1-gedv4 | 2021-03-29 23:00:47,618 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 47km6iougl-algo-1-gedv4 | 2021-03-29 23:00:47,831 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 47km6iougl-algo-1-gedv4 | 2021-03-29 23:00:47,852 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 47km6iougl-algo-1-gedv4 | 2021-03-29 23:00:47,872 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 47km6iougl-algo-1-gedv4 | 2021-03-29 23:00:47,885 sagemaker-training-toolkit INFO     Invoking user script
# 47km6iougl-algo-1-gedv4 |
# 47km6iougl-algo-1-gedv4 | Training Env:
# 47km6iougl-algo-1-gedv4 |
# 47km6iougl-algo-1-gedv4 | {
# 47km6iougl-algo-1-gedv4 |     "additional_framework_parameters": {},
# 47km6iougl-algo-1-gedv4 |     "channel_input_dirs": {
# 47km6iougl-algo-1-gedv4 |         "train": "/opt/ml/input/data/train",
# 47km6iougl-algo-1-gedv4 |         "validation": "/opt/ml/input/data/validation",
# 47km6iougl-algo-1-gedv4 |         "eval": "/opt/ml/input/data/eval"
# 47km6iougl-algo-1-gedv4 |     },
# 47km6iougl-algo-1-gedv4 |     "current_host": "algo-1-gedv4",
# 47km6iougl-algo-1-gedv4 |     "framework_module": "sagemaker_tensorflow_container.training:main",
# 47km6iougl-algo-1-gedv4 |     "hosts": [
# 47km6iougl-algo-1-gedv4 |         "algo-1-gedv4"
# 47km6iougl-algo-1-gedv4 |     ],
# 47km6iougl-algo-1-gedv4 |     "hyperparameters": {
# 47km6iougl-algo-1-gedv4 |         "epochs": 1,
# 47km6iougl-algo-1-gedv4 |         "model": "s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/",
# 47km6iougl-algo-1-gedv4 |         "train": "s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/train.tfrecords",
# 47km6iougl-algo-1-gedv4 |         "validation": "s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords",
# 47km6iougl-algo-1-gedv4 |         "eval": "s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords",
# 47km6iougl-algo-1-gedv4 |         "model_version": 1,
# 47km6iougl-algo-1-gedv4 |         "model_dir": "s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-29-22-47-28-925/model"
# 47km6iougl-algo-1-gedv4 |     },
# 47km6iougl-algo-1-gedv4 |     "input_config_dir": "/opt/ml/input/config",
# 47km6iougl-algo-1-gedv4 |     "input_data_config": {
# 47km6iougl-algo-1-gedv4 |         "train": {
# 47km6iougl-algo-1-gedv4 |             "TrainingInputMode": "File"
# 47km6iougl-algo-1-gedv4 |         },
# 47km6iougl-algo-1-gedv4 |         "validation": {
# 47km6iougl-algo-1-gedv4 |             "TrainingInputMode": "File"
# 47km6iougl-algo-1-gedv4 |         },
# 47km6iougl-algo-1-gedv4 |         "eval": {
# 47km6iougl-algo-1-gedv4 |             "TrainingInputMode": "File"
# 47km6iougl-algo-1-gedv4 |         }
# 47km6iougl-algo-1-gedv4 |     },
# 47km6iougl-algo-1-gedv4 |     "input_dir": "/opt/ml/input",
# 47km6iougl-algo-1-gedv4 |     "is_master": true,
# 47km6iougl-algo-1-gedv4 |     "job_name": "robot_reboot-2021-03-29-23-00-38-951",
# 47km6iougl-algo-1-gedv4 |     "log_level": 20,
# 47km6iougl-algo-1-gedv4 |     "master_hostname": "algo-1-gedv4",
# 47km6iougl-algo-1-gedv4 |     "model_dir": "/opt/ml/model",
# 47km6iougl-algo-1-gedv4 |     "module_dir": "s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-29-23-00-38-951/source/sourcedir.tar.gz",
# 47km6iougl-algo-1-gedv4 |     "module_name": "train",
# 47km6iougl-algo-1-gedv4 |     "network_interface_name": "eth0",
# 47km6iougl-algo-1-gedv4 |     "num_cpus": 2,
# 47km6iougl-algo-1-gedv4 |     "num_gpus": 0,
# 47km6iougl-algo-1-gedv4 |     "output_data_dir": "/opt/ml/output/data",
# 47km6iougl-algo-1-gedv4 |     "output_dir": "/opt/ml/output",
# 47km6iougl-algo-1-gedv4 |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# 47km6iougl-algo-1-gedv4 |     "resource_config": {
# 47km6iougl-algo-1-gedv4 |         "current_host": "algo-1-gedv4",
# 47km6iougl-algo-1-gedv4 |         "hosts": [
# 47km6iougl-algo-1-gedv4 |             "algo-1-gedv4"
# 47km6iougl-algo-1-gedv4 |         ]
# 47km6iougl-algo-1-gedv4 |     },
# 47km6iougl-algo-1-gedv4 |     "user_entry_point": "train.py"
# 47km6iougl-algo-1-gedv4 | }
# 47km6iougl-algo-1-gedv4 |
# 47km6iougl-algo-1-gedv4 | Environment variables:
# 47km6iougl-algo-1-gedv4 |
# 47km6iougl-algo-1-gedv4 | SM_HOSTS=["algo-1-gedv4"]
# 47km6iougl-algo-1-gedv4 | SM_NETWORK_INTERFACE_NAME=eth0
# 47km6iougl-algo-1-gedv4 | SM_HPS={"epochs":1,"eval":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords","model":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/","model_dir":"s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-29-22-47-28-925/model","model_version":1,"train":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/train.tfrecords","validation":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords"}
# 47km6iougl-algo-1-gedv4 | SM_USER_ENTRY_POINT=train.py
# 47km6iougl-algo-1-gedv4 | SM_FRAMEWORK_PARAMS={}
# 47km6iougl-algo-1-gedv4 | SM_RESOURCE_CONFIG={"current_host":"algo-1-gedv4","hosts":["algo-1-gedv4"]}
# 47km6iougl-algo-1-gedv4 | SM_INPUT_DATA_CONFIG={"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}}
# 47km6iougl-algo-1-gedv4 | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# 47km6iougl-algo-1-gedv4 | SM_CHANNELS=["eval","train","validation"]
# 47km6iougl-algo-1-gedv4 | SM_CURRENT_HOST=algo-1-gedv4
# 47km6iougl-algo-1-gedv4 | SM_MODULE_NAME=train
# 47km6iougl-algo-1-gedv4 | SM_LOG_LEVEL=20
# 47km6iougl-algo-1-gedv4 | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# 47km6iougl-algo-1-gedv4 | SM_INPUT_DIR=/opt/ml/input
# 47km6iougl-algo-1-gedv4 | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# 47km6iougl-algo-1-gedv4 | SM_OUTPUT_DIR=/opt/ml/output
# 47km6iougl-algo-1-gedv4 | SM_NUM_CPUS=2
# 47km6iougl-algo-1-gedv4 | SM_NUM_GPUS=0
# 47km6iougl-algo-1-gedv4 | SM_MODEL_DIR=/opt/ml/model
# 47km6iougl-algo-1-gedv4 | SM_MODULE_DIR=s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-29-23-00-38-951/source/sourcedir.tar.gz
# 47km6iougl-algo-1-gedv4 | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1-gedv4","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-gedv4"],"hyperparameters":{"epochs":1,"eval":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords","model":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/","model_dir":"s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-29-22-47-28-925/model","model_version":1,"train":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/train.tfrecords","validation":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"robot_reboot-2021-03-29-23-00-38-951","log_level":20,"master_hostname":"algo-1-gedv4","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-29-23-00-38-951/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-gedv4","hosts":["algo-1-gedv4"]},"user_entry_point":"train.py"}
# 47km6iougl-algo-1-gedv4 | SM_USER_ARGS=["--epochs","1","--eval","s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords","--model","s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/","--model_dir","s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-29-22-47-28-925/model","--model_version","1","--train","s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/train.tfrecords","--validation","s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords"]
# 47km6iougl-algo-1-gedv4 | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# 47km6iougl-algo-1-gedv4 | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# 47km6iougl-algo-1-gedv4 | SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# 47km6iougl-algo-1-gedv4 | SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# 47km6iougl-algo-1-gedv4 | SM_HP_EPOCHS=1
# 47km6iougl-algo-1-gedv4 | SM_HP_MODEL=s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/
# 47km6iougl-algo-1-gedv4 | SM_HP_TRAIN=s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/train.tfrecords
# 47km6iougl-algo-1-gedv4 | SM_HP_VALIDATION=s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords
# 47km6iougl-algo-1-gedv4 | SM_HP_EVAL=s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords
# 47km6iougl-algo-1-gedv4 | SM_HP_MODEL_VERSION=1
# 47km6iougl-algo-1-gedv4 | SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-29-22-47-28-925/model
# 47km6iougl-algo-1-gedv4 | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# 47km6iougl-algo-1-gedv4 |
# 47km6iougl-algo-1-gedv4 | Invoking script with the following command:
# 47km6iougl-algo-1-gedv4 |
# 47km6iougl-algo-1-gedv4 | /usr/local/bin/python3.7 train.py --epochs 1 --eval s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords --model s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/ --model_dir s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-29-22-47-28-925/model --model_version 1 --train s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/train.tfrecords --validation s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords
# 47km6iougl-algo-1-gedv4 |
# 47km6iougl-algo-1-gedv4 |
# 47km6iougl-algo-1-gedv4 | 2021-03-29 23:02:23,352 sagemaker-training-toolkit ERROR    ExecuteUserScriptError:
# 47km6iougl-algo-1-gedv4 | Command "/usr/local/bin/python3.7 train.py --epochs 1 --eval s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords --model s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/ --model_dir s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-29-22-47-28-925/model --model_version 1 --train s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/train.tfrecords --validation s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords"
# 47km6iougl-algo-1-gedv4 | 2021-03-29 23:00:48.198444: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:425] Initializing the SageMaker Profiler.
# 47km6iougl-algo-1-gedv4 | 2021-03-29 23:00:48.198595: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:106] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 47km6iougl-algo-1-gedv4 | 2021-03-29 23:00:48.221296: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:425] Initializing the SageMaker Profiler.
# 47km6iougl-algo-1-gedv4 | INFO:root:Getting data sets
# 47km6iougl-algo-1-gedv4 | INFO:root:Loading data for train
# 47km6iougl-algo-1-gedv4 | INFO:root:Loading data for validation
# 47km6iougl-algo-1-gedv4 | INFO:root:Loading data for eval
# 47km6iougl-algo-1-gedv4 | INFO:root:Loading model
# 47km6iougl-algo-1-gedv4 | INFO:root:Starting to train
# 47km6iougl-algo-1-gedv4 | Traceback (most recent call last):
# 47km6iougl-algo-1-gedv4 |   File "train.py", line 143, in <module>
# 47km6iougl-algo-1-gedv4 |     train(args)
# 47km6iougl-algo-1-gedv4 |   File "train.py", line 79, in train
# 47km6iougl-algo-1-gedv4 |     model.fit(train_ds)  # , epochs=args.epochs, validation_data=valid_ds, callbacks=[checkpoint])
# 47km6iougl-algo-1-gedv4 |   File "/usr/local/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 67, in _method_wrapper
# 47km6iougl-algo-1-gedv4 |     return method(self, *args, **kwargs)
# 47km6iougl-algo-1-gedv4 |   File "/usr/local/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 869, in fit
# 47km6iougl-algo-1-gedv4 |     tmp_logs = train_function(iterator)
# 47km6iougl-algo-1-gedv4 |   File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 580, in __call__
# 47km6iougl-algo-1-gedv4 |     result = self._call(*args, **kwds)
# 47km6iougl-algo-1-gedv4 |   File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py", line 644, in _call
# 47km6iougl-algo-1-gedv4 |     return self._stateless_fn(*args, **kwds)
# 47km6iougl-algo-1-gedv4 |   File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 2422, in __call__
# 47km6iougl-algo-1-gedv4 |     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
# 47km6iougl-algo-1-gedv4 |   File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 1667, in _filtered_call
# 47km6iougl-algo-1-gedv4 |     self.captured_inputs)
# 47km6iougl-algo-1-gedv4 |   File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 1748, in _call_flat
# 47km6iougl-algo-1-gedv4 |     ctx, args, cancellation_manager=cancellation_manager))
# 47km6iougl-algo-1-gedv4 |   File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/function.py", line 600, in call
# 47km6iougl-algo-1-gedv4 |     ctx=ctx)
# 47km6iougl-algo-1-gedv4 |   File "/usr/local/lib/python3.7/site-packages/tensorflow/python/eager/execute.py", line 60, in quick_execute
# 47km6iougl-algo-1-gedv4 |     inputs, attrs, num_outputs)
# 47km6iougl-algo-1-gedv4 | tensorflow.python.framework.errors_impl.AbortedError:  All 10 retry attempts failed. The last failure: Unknown: : No response body.
# 47km6iougl-algo-1-gedv4 | 	 [[node IteratorGetNext (defined at train.py:79) ]] [Op:__inference_train_function_1490]
# 47km6iougl-algo-1-gedv4 |
# 47km6iougl-algo-1-gedv4 | Function call stack:
# 47km6iougl-algo-1-gedv4 | train_function
# 47km6iougl-algo-1-gedv4 exited with code 1
# 1
# Aborting on container exit...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     237         try:
# --> 238             _stream_output(process)
#     239         except RuntimeError as e:
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/local/image.py in _stream_output(process)
#     893     if exit_code != 0:
# --> 894         raise RuntimeError("Process exited with code: %s" % exit_code)
#     895
#
# RuntimeError: Process exited with code: 1
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-37487b3efb5f> in <module>
#       1 estimator.fit({'train': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/train.tfrecords',
#       2               'validation': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords',
# ----> 3               'eval': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords'})
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     659                 'ExperimentName', 'TrialName', and 'TrialComponentDisplayName'.
#     660
# --> 661         """
#     662         self._prepare_for_training(job_name=job_name)
#     663
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/estimator.py in start_new(cls, estimator, inputs, experiment_config)
#    1422         Returns:
#    1423             sagemaker.estimator._TrainingJob: Constructed object that captures
# -> 1424             all information about the started training job.
#    1425         """
#    1426         train_args = cls._get_train_args(estimator, inputs, experiment_config)
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/session.py in train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image_uri, algorithm_arn, encrypt_inter_container_traffic, use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics, profiler_rule_configs, profiler_config)
#     560         LOGGER.info("Creating training-job with name: %s", job_name)
#     561         LOGGER.debug("train request: %s", json.dumps(train_request, indent=4))
# --> 562         self.sagemaker_client.create_training_job(**train_request)
#     563
#     564     def _get_train_request(  # noqa: C901
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/local/local_session.py in create_training_job(self, TrainingJobName, AlgorithmSpecification, OutputDataConfig, ResourceConfig, InputDataConfig, **kwargs)
#     184         hyperparameters = kwargs["HyperParameters"] if "HyperParameters" in kwargs else {}
#     185         logger.info("Starting training job")
# --> 186         training_job.start(InputDataConfig, OutputDataConfig, hyperparameters, TrainingJobName)
#     187
#     188         LocalSagemakerClient._training_jobs[TrainingJobName] = training_job
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/local/entities.py in start(self, input_data_config, output_data_config, hyperparameters, job_name)
#     219
#     220         self.model_artifacts = self.container.train(
# --> 221             input_data_config, output_data_config, hyperparameters, job_name
#     222         )
#     223         self.end_time = datetime.datetime.now()
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     241             # which contains the exit code and append the command line to it.
#     242             msg = "Failed to run: %s, %s" % (compose_command, str(e))
# --> 243             raise RuntimeError(msg)
#     244         finally:
#     245             artifacts = self.retrieve_artifacts(compose_data, output_data_config, job_name)
#
# RuntimeError: Failed to run: ['docker-compose', '-f', '/tmp/tmpsa2wg7oi/docker-compose.yaml', 'up', '--build', '--abort-on-container-exit'], Process exited with code: 1
