# %%
import boto3
import sagemaker

# %%
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

bucket = sagemaker_session.default_bucket()

# %%
bucket
# Out:
# 'sagemaker-us-east-1-322961843176'

# %% [markdown]
# ### Upload training data to S3

# %%
data_dir = 'robot_reboot_data'
prefix = 'sagemaker/robot_reboot'
input_data = sagemaker_session.upload_data(path=data_dir, bucket=bucket, key_prefix=prefix)

# %%
sagemaker_session.upload_data(path='robot_reboot_model', bucket=bucket, key_prefix=prefix)
# Out:
# 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot'

# %%
for obj in boto3.resource('s3').Bucket(bucket).objects.all():
    print(obj.key)
# Out:
# sagemaker/robot_reboot/model_0/.data-00000-of-00001
# sagemaker/robot_reboot/model_0/.index
# sagemaker/robot_reboot/model_0/checkpoint
# sagemaker/robot_reboot/train.tfrecords
# sagemaker/robot_reboot/validation.tfrecords

# %%
# !pygmentize src/ml/train.py
# Out:
# import argparse
# import logging
# import os
#
# import tensorflow as tf
# from tensorflow.keras.callbacks import ModelCheckpoint
# from model import get_model
#
# logging.getLogger().setLevel(logging.INFO)
#
# HEIGHT = 31
# WIDTH = 31
# DEPTH = 9
# NUM_CLASSES = 16
# SHUFFLE_BUFFER_SIZE = 100
#
#
# def get_filenames(channel_name, channel):
#     if channel_name in ['train', 'validation', 'eval']:
#         return [os.path.join(channel, f'{channel_name}.tfrecords')]
#     else:
#         raise ValueError(f'Invalid data for {channel_name}')
#
#
# def read_tfrecord(example):
#     feature_desc = {
#         'v': tf.io.FixedLenFeature([], tf.float32),
#         'p': tf.io.VarLenFeature(tf.float32),
#         's': tf.io.VarLenFeature(tf.float32)
#     }
#     parsed = tf.io.parse_single_example(example, feature_desc)
#     x = tf.reshape(tf.sparse.to_dense(parsed['s']), (1, HEIGHT, WIDTH, DEPTH))
#     p = tf.reshape(tf.sparse.to_dense(parsed['p']), (1, 16))
#     v = tf.reshape(parsed['v'], (1, 1))
#
#     y = {'v': v, 'p': p}
#     return x, y
#
#
# def _input(epochs, channel, channel_name):
#     logging.info(f'Loading data for {channel_name}')
#
#     filenames = get_filenames(channel_name, channel)
#     dataset = tf.data.TFRecordDataset(filenames)
#     dataset = dataset.map(read_tfrecord, num_parallel_calls=20)
#
#     if channel_name == 'train':
#         dataset = dataset.repeat(epochs)
#         dataset = dataset.shuffle(SHUFFLE_BUFFER_SIZE).prefetch(1)
#
#     return dataset
#
#
# def save_model(model, dir, version):
#     output = os.path.join(dir, 'model_' + version)
#     model.save(output)
#
#     logging.info("Model successfully saved at: {}".format(output))
#
#
# def train(args):
#     logging.info("Getting data sets")
#     train_ds = _input(args.epochs, args.train, 'train')
#     valid_ds = _input(args.epochs, args.validation, 'validation')
#     eval_ds = _input(args.epochs, args.eval, 'eval')
#
#     logging.info("Loading model")
#     model = get_model((31, 31, 9), n_outputs=16, convolutions=3, optimizer='adam', seed=26)
#     model.load_weights(args.model)
#
#     losses = {
#         "v": 'mean_squared_error',
#         "p": tf.keras.losses.BinaryCrossentropy()
#     }
#     model.compile(loss=losses, optimizer=args.optimizer, metrics=[tf.keras.metrics.Accuracy()])
#
#     checkpoint = ModelCheckpoint(args.model_output_dir + 'checkpoint-{epoch}.h5')
#
#     logging.info("Starting to train")
#     model.fit(train_ds , epochs=args.epochs, validation_data=valid_ds, callbacks=[checkpoint])
#
#     logging.info("Evaluating the model")
#     v_eval, p_eval = model.evaluate(eval_ds)
#
#     logging.info('Test loss v:{}'.format(v_eval))
#     logging.info('Tess loss p:{}'.format(p_eval))
#
#     return save_model(model, args.model_output_dir, args.model_version)
#
#
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#     parser.add_argument(
#         '--train',
#         type=str,
#         required=True,
#         default=os.environ.get('SM_CHANNEL_TRAIN'),
#         help='Directory where the robot reboot training data is stored'
#     )
#     parser.add_argument(
#         '--validation',
#         type=str,
#         required=True,
#         default=os.environ.get('SM_CHANNEL_VALIDATION'),
#         help='Directory where the robot reboot validation data is stored'
#     )
#     parser.add_argument(
#         '--eval',
#         type=str,
#         required=True,
#         default=os.environ.get('SM_CHANNEL_EVAL'),
#         help='Directory where the robot reboot evaluation data is stored'
#     )
#     parser.add_argument(
#         '--model',
#         type=str,
#         required=True,
#         help='Directory where the current model is stored'
#     )
#     parser.add_argument(
#         '--model_dir',
#         type=str,
#         required=True,
#         help='Directory where the model will be stored'
#     )
#     parser.add_argument(
#         '--model_output_dir',
#         type=str,
#         default=os.environ.get('SM_MODEL_DIR')
#     )
#     parser.add_argument(
#         '--model_version',
#         type=str,
#         required=True,
#         help='Directory where the model will be stored'
#     )
#     parser.add_argument(
#         '--epochs',
#         type=int,
#         default=10,
#         help='The number of steps to use for training.'
#     ),
#     parser.add_argument(
#         '--optimizer',
#         type=str,
#         default='adam',
#         help='Optimizer to train the model.'
#     )
#     args = parser.parse_args()
#     train(args)

# %% [markdown]
# ### Create estimator

# %%
# !pip install --upgrade sagemaker
# Out:
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (2.31.0)
# Collecting sagemaker
#   Downloading sagemaker-2.32.0.tar.gz (405 kB)
#      |████████████████████████████████| 405 kB 17.2 MB/s eta 0:00:01
# Requirement already satisfied: attrs in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (20.3.0)
# Requirement already satisfied: boto3>=1.16.32 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (1.17.34)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (1.18.5)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (3.15.2)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: smdebug_rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (3.7.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (20.9)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (1.1.5)
# Requirement already satisfied: botocore<1.21.0,>=1.20.34 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (1.20.34)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.3.4)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.34->boto3>=1.16.32->sagemaker) (1.26.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.34->boto3>=1.16.32->sagemaker) (2.8.1)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from packaging>=20.0->sagemaker) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker) (1.15.0)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from pandas->sagemaker) (2021.1)
# Building wheels for collected packages: sagemaker
#   Building wheel for sagemaker (setup.py) ... done
#   Created wheel for sagemaker: filename=sagemaker-2.32.0-py2.py3-none-any.whl size=570899 sha256=0e480fdc36e8b22e324376ecede44846de207f119bbceee47903af4b694bd9e9
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/69/97/97/3cc021580a00f6ec531125f88d49baf9ec4385afabe45ecf11
# Successfully built sagemaker
# Installing collected packages: sagemaker
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.31.0
#     Uninstalling sagemaker-2.31.0:
#       Successfully uninstalled sagemaker-2.31.0
# Successfully installed sagemaker-2.32.0

# %%
from sagemaker.tensorflow import TensorFlow
estimator = TensorFlow(base_job_name='robot_reboot',
                      entry_point='train.py',
                      source_dir='src/ml',
                      role=role,
                      framework_version="2.2.0",
                      py_version='py37',
                      hyperparameters={
                          'epochs': 1,
                          'model': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/',
                          'train': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot',
                          'validation': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot',
                          'eval': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot',
                          'model_version': 1, 
                          'optimizer': 'sgd',
                          'learning_rate': 0.01
                      },
                      train_instance_count=1, 
                      train_instance_type='local')

# %%
estimator.fit({'train': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/train.tfrecords',
              'validation': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords',
              'eval': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords'})
# Out:
# Creating 9a4wozzkmt-algo-1-575yo ...
# Creating 9a4wozzkmt-algo-1-575yo ... done
# Attaching to 9a4wozzkmt-algo-1-575yo
# 9a4wozzkmt-algo-1-575yo | 2021-03-31 22:13:08.749991: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:425] Initializing the SageMaker Profiler.
# 9a4wozzkmt-algo-1-575yo | 2021-03-31 22:13:08.750172: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:106] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 9a4wozzkmt-algo-1-575yo | 2021-03-31 22:13:08.773741: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:425] Initializing the SageMaker Profiler.
# 9a4wozzkmt-algo-1-575yo | 2021-03-31 22:13:10,864 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 9a4wozzkmt-algo-1-575yo | 2021-03-31 22:13:10,871 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 9a4wozzkmt-algo-1-575yo | 2021-03-31 22:13:11,095 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 9a4wozzkmt-algo-1-575yo | 2021-03-31 22:13:11,116 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 9a4wozzkmt-algo-1-575yo | 2021-03-31 22:13:11,135 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 9a4wozzkmt-algo-1-575yo | 2021-03-31 22:13:11,148 sagemaker-training-toolkit INFO     Invoking user script
# 9a4wozzkmt-algo-1-575yo |
# 9a4wozzkmt-algo-1-575yo | Training Env:
# 9a4wozzkmt-algo-1-575yo |
# 9a4wozzkmt-algo-1-575yo | {
# 9a4wozzkmt-algo-1-575yo |     "additional_framework_parameters": {},
# 9a4wozzkmt-algo-1-575yo |     "channel_input_dirs": {
# 9a4wozzkmt-algo-1-575yo |         "train": "/opt/ml/input/data/train",
# 9a4wozzkmt-algo-1-575yo |         "validation": "/opt/ml/input/data/validation",
# 9a4wozzkmt-algo-1-575yo |         "eval": "/opt/ml/input/data/eval"
# 9a4wozzkmt-algo-1-575yo |     },
# 9a4wozzkmt-algo-1-575yo |     "current_host": "algo-1-575yo",
# 9a4wozzkmt-algo-1-575yo |     "framework_module": "sagemaker_tensorflow_container.training:main",
# 9a4wozzkmt-algo-1-575yo |     "hosts": [
# 9a4wozzkmt-algo-1-575yo |         "algo-1-575yo"
# 9a4wozzkmt-algo-1-575yo |     ],
# 9a4wozzkmt-algo-1-575yo |     "hyperparameters": {
# 9a4wozzkmt-algo-1-575yo |         "epochs": 1,
# 9a4wozzkmt-algo-1-575yo |         "model": "s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/",
# 9a4wozzkmt-algo-1-575yo |         "train": "s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot",
# 9a4wozzkmt-algo-1-575yo |         "validation": "s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot",
# 9a4wozzkmt-algo-1-575yo |         "eval": "s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot",
# 9a4wozzkmt-algo-1-575yo |         "model_version": 1,
# 9a4wozzkmt-algo-1-575yo |         "optimizer": "RMSprop",
# 9a4wozzkmt-algo-1-575yo |         "learning_rate": 0.01,
# 9a4wozzkmt-algo-1-575yo |         "model_dir": "s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-31-21-20-14-550/model"
# 9a4wozzkmt-algo-1-575yo |     },
# 9a4wozzkmt-algo-1-575yo |     "input_config_dir": "/opt/ml/input/config",
# 9a4wozzkmt-algo-1-575yo |     "input_data_config": {
# 9a4wozzkmt-algo-1-575yo |         "train": {
# 9a4wozzkmt-algo-1-575yo |             "TrainingInputMode": "File"
# 9a4wozzkmt-algo-1-575yo |         },
# 9a4wozzkmt-algo-1-575yo |         "validation": {
# 9a4wozzkmt-algo-1-575yo |             "TrainingInputMode": "File"
# 9a4wozzkmt-algo-1-575yo |         },
# 9a4wozzkmt-algo-1-575yo |         "eval": {
# 9a4wozzkmt-algo-1-575yo |             "TrainingInputMode": "File"
# 9a4wozzkmt-algo-1-575yo |         }
# 9a4wozzkmt-algo-1-575yo |     },
# 9a4wozzkmt-algo-1-575yo |     "input_dir": "/opt/ml/input",
# 9a4wozzkmt-algo-1-575yo |     "is_master": true,
# 9a4wozzkmt-algo-1-575yo |     "job_name": "robot_reboot-2021-03-31-22-12-59-877",
# 9a4wozzkmt-algo-1-575yo |     "log_level": 20,
# 9a4wozzkmt-algo-1-575yo |     "master_hostname": "algo-1-575yo",
# 9a4wozzkmt-algo-1-575yo |     "model_dir": "/opt/ml/model",
# 9a4wozzkmt-algo-1-575yo |     "module_dir": "s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-31-22-12-59-877/source/sourcedir.tar.gz",
# 9a4wozzkmt-algo-1-575yo |     "module_name": "train",
# 9a4wozzkmt-algo-1-575yo |     "network_interface_name": "eth0",
# 9a4wozzkmt-algo-1-575yo |     "num_cpus": 2,
# 9a4wozzkmt-algo-1-575yo |     "num_gpus": 0,
# 9a4wozzkmt-algo-1-575yo |     "output_data_dir": "/opt/ml/output/data",
# 9a4wozzkmt-algo-1-575yo |     "output_dir": "/opt/ml/output",
# 9a4wozzkmt-algo-1-575yo |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# 9a4wozzkmt-algo-1-575yo |     "resource_config": {
# 9a4wozzkmt-algo-1-575yo |         "current_host": "algo-1-575yo",
# 9a4wozzkmt-algo-1-575yo |         "hosts": [
# 9a4wozzkmt-algo-1-575yo |             "algo-1-575yo"
# 9a4wozzkmt-algo-1-575yo |         ]
# 9a4wozzkmt-algo-1-575yo |     },
# 9a4wozzkmt-algo-1-575yo |     "user_entry_point": "train.py"
# 9a4wozzkmt-algo-1-575yo | }
# 9a4wozzkmt-algo-1-575yo |
# 9a4wozzkmt-algo-1-575yo | Environment variables:
# 9a4wozzkmt-algo-1-575yo |
# 9a4wozzkmt-algo-1-575yo | SM_HOSTS=["algo-1-575yo"]
# 9a4wozzkmt-algo-1-575yo | SM_NETWORK_INTERFACE_NAME=eth0
# 9a4wozzkmt-algo-1-575yo | SM_HPS={"epochs":1,"eval":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot","learning_rate":0.01,"model":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/","model_dir":"s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-31-21-20-14-550/model","model_version":1,"optimizer":"RMSprop","train":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot","validation":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot"}
# 9a4wozzkmt-algo-1-575yo | SM_USER_ENTRY_POINT=train.py
# 9a4wozzkmt-algo-1-575yo | SM_FRAMEWORK_PARAMS={}
# 9a4wozzkmt-algo-1-575yo | SM_RESOURCE_CONFIG={"current_host":"algo-1-575yo","hosts":["algo-1-575yo"]}
# 9a4wozzkmt-algo-1-575yo | SM_INPUT_DATA_CONFIG={"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}}
# 9a4wozzkmt-algo-1-575yo | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# 9a4wozzkmt-algo-1-575yo | SM_CHANNELS=["eval","train","validation"]
# 9a4wozzkmt-algo-1-575yo | SM_CURRENT_HOST=algo-1-575yo
# 9a4wozzkmt-algo-1-575yo | SM_MODULE_NAME=train
# 9a4wozzkmt-algo-1-575yo | SM_LOG_LEVEL=20
# 9a4wozzkmt-algo-1-575yo | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# 9a4wozzkmt-algo-1-575yo | SM_INPUT_DIR=/opt/ml/input
# 9a4wozzkmt-algo-1-575yo | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# 9a4wozzkmt-algo-1-575yo | SM_OUTPUT_DIR=/opt/ml/output
# 9a4wozzkmt-algo-1-575yo | SM_NUM_CPUS=2
# 9a4wozzkmt-algo-1-575yo | SM_NUM_GPUS=0
# 9a4wozzkmt-algo-1-575yo | SM_MODEL_DIR=/opt/ml/model
# 9a4wozzkmt-algo-1-575yo | SM_MODULE_DIR=s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-31-22-12-59-877/source/sourcedir.tar.gz
# 9a4wozzkmt-algo-1-575yo | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1-575yo","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-575yo"],"hyperparameters":{"epochs":1,"eval":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot","learning_rate":0.01,"model":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/","model_dir":"s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-31-21-20-14-550/model","model_version":1,"optimizer":"RMSprop","train":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot","validation":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"robot_reboot-2021-03-31-22-12-59-877","log_level":20,"master_hostname":"algo-1-575yo","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-31-22-12-59-877/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-575yo","hosts":["algo-1-575yo"]},"user_entry_point":"train.py"}
# 9a4wozzkmt-algo-1-575yo | SM_USER_ARGS=["--epochs","1","--eval","s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot","--learning_rate","0.01","--model","s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/","--model_dir","s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-31-21-20-14-550/model","--model_version","1","--optimizer","RMSprop","--train","s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot","--validation","s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot"]
# 9a4wozzkmt-algo-1-575yo | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# 9a4wozzkmt-algo-1-575yo | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# 9a4wozzkmt-algo-1-575yo | SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# 9a4wozzkmt-algo-1-575yo | SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# 9a4wozzkmt-algo-1-575yo | SM_HP_EPOCHS=1
# 9a4wozzkmt-algo-1-575yo | SM_HP_MODEL=s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/
# 9a4wozzkmt-algo-1-575yo | SM_HP_TRAIN=s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot
# 9a4wozzkmt-algo-1-575yo | SM_HP_VALIDATION=s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot
# 9a4wozzkmt-algo-1-575yo | SM_HP_EVAL=s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot
# 9a4wozzkmt-algo-1-575yo | SM_HP_MODEL_VERSION=1
# 9a4wozzkmt-algo-1-575yo | SM_HP_OPTIMIZER=RMSprop
# 9a4wozzkmt-algo-1-575yo | SM_HP_LEARNING_RATE=0.01
# 9a4wozzkmt-algo-1-575yo | SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-31-21-20-14-550/model
# 9a4wozzkmt-algo-1-575yo | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# 9a4wozzkmt-algo-1-575yo |
# 9a4wozzkmt-algo-1-575yo | Invoking script with the following command:
# 9a4wozzkmt-algo-1-575yo |
# 9a4wozzkmt-algo-1-575yo | /usr/local/bin/python3.7 train.py --epochs 1 --eval s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot --learning_rate 0.01 --model s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/ --model_dir s3://sagemaker-us-east-1-322961843176/robot_reboot-2021-03-31-21-20-14-550/model --model_version 1 --optimizer RMSprop --train s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot --validation s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot
# 9a4wozzkmt-algo-1-575yo |
# 9a4wozzkmt-algo-1-575yo |
# 3500/3500 [==============================] - 33s 9ms/step - loss: 0.7526 - v_loss: 0.0300 - p_loss: 0.7226 - v_accuracy: 0.1334 - p_accuracy: 0.1102 - val_loss: 0.4720 - val_v_loss: 0.0087 - val_p_loss: 0.4634 - val_v_accuracy: 0.1940 - val_p_accuracy: 0.1335
# 9a4wozzkmt-algo-1-575yo | 2021-03-31 22:13:53,740 sagemaker_tensorflow_container.training WARNING  Your model will NOT be servable with SageMaker TensorFlow Serving containers. The SavedModel bundle is under directory "model_1", not a numeric name.
# 9a4wozzkmt-algo-1-575yo | 2021-03-31 22:13:53,741 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# 9a4wozzkmt-algo-1-575yo exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %%
from sagemaker.tensorflow import TensorFlow

metric_definitions = [
    {'Name': 'loss', 'Regex': 'loss: ([0-9\\.]+)'},
    {'Name': 'v_loss', 'Regex': 'v_loss: ([0-9\\.]+)'},
    {'Name': 'p_loss', 'Regex': 'p_loss: ([0-9\\.]+)'},
    {'Name': 'v_accuracy', 'Regex': 'v_accuracy: ([0-9\\.]+)'},
    {'Name': 'p_accuracy', 'Regex': 'p_accuracy: ([0-9\\.]+)'}
]

estimator = TensorFlow(base_job_name='robot-reboot',
                      entry_point='train.py',
                      source_dir='src/ml',
                      role=role,
                      framework_version="2.2.0",
                      py_version='py37',
                      metric_definitions=metric_definitions,
                      hyperparameters={
                          'epochs': 20,
                          'model': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/',
                          'train': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot',
                          'validation': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot',
                          'eval': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot',
                          'model_version': 1,
                          'optimizer': 'sgd',
                          'learning_rate': 0.01
                      },
                      train_instance_count=1, 
                      train_instance_type='ml.c4.xlarge')
# Out:
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
estimator.fit({'train': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/train.tfrecords',
              'validation': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords',
              'eval': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords'})
# Out:
# 2021-03-31 01:27:58 Starting - Starting the training job...
# 2021-03-31 01:28:24 Starting - Launching requested ML instancesProfilerReport-1617154077: InProgress
# ......
# 2021-03-31 01:29:24 Starting - Preparing the instances for training......
# 2021-03-31 01:30:24 Downloading - Downloading input data...
# 2021-03-31 01:30:49 Training - Training image download completed. Training in progress.2021-03-31 01:30:51.097287: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:425] Initializing the SageMaker Profiler.
# 2021-03-31 01:30:51.104686: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:106] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-03-31 01:30:51.271422: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:425] Initializing the SageMaker Profiler.
# 2021-03-31 01:30:55,561 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-03-31 01:30:55,569 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-03-31 01:30:56,001 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-03-31 01:30:56,017 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-03-31 01:30:56,033 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-03-31 01:30:56,044 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "model_version": 1,
#         "eval": "s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot",
#         "model": "s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/",
#         "model_dir": "s3://sagemaker-us-east-1-322961843176/robot-reboot-2021-03-31-01-27-57-477/model",
#         "epochs": 100,
#         "validation": "s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot",
#         "train": "s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "robot-reboot-2021-03-31-01-27-57-477",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-322961843176/robot-reboot-2021-03-31-01-27-57-477/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":100,"eval":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot","model":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/","model_dir":"s3://sagemaker-us-east-1-322961843176/robot-reboot-2021-03-31-01-27-57-477/model","model_version":1,"train":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot","validation":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-322961843176/robot-reboot-2021-03-31-01-27-57-477/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":100,"eval":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot","model":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/","model_dir":"s3://sagemaker-us-east-1-322961843176/robot-reboot-2021-03-31-01-27-57-477/model","model_version":1,"train":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot","validation":"s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"robot-reboot-2021-03-31-01-27-57-477","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-322961843176/robot-reboot-2021-03-31-01-27-57-477/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--epochs","100","--eval","s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot","--model","s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/","--model_dir","s3://sagemaker-us-east-1-322961843176/robot-reboot-2021-03-31-01-27-57-477/model","--model_version","1","--train","s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot","--validation","s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_VERSION=1
# SM_HP_EVAL=s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot
# SM_HP_MODEL=s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-322961843176/robot-reboot-2021-03-31-01-27-57-477/model
# SM_HP_EPOCHS=100
# SM_HP_VALIDATION=s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot
# SM_HP_TRAIN=s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.7 train.py --epochs 100 --eval s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot --model s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/model_0/ --model_dir s3://sagemaker-us-east-1-322961843176/robot-reboot-2021-03-31-01-27-57-477/model --model_version 1 --train s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot --validation s3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot
#
#
# [2021-03-31 01:30:59.965 ip-10-0-144-123.ec2.internal:21 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-03-31 01:30:59.966 ip-10-0-144-123.ec2.internal:21 INFO hook.py:193] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-03-31 01:30:59.966 ip-10-0-144-123.ec2.internal:21 INFO hook.py:238] Saving to /opt/ml/output/tensors
# [2021-03-31 01:30:59.966 ip-10-0-144-123.ec2.internal:21 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# Epoch 1/100
# [2021-03-31 01:31:00.181 ip-10-0-144-123.ec2.internal:21 INFO hook.py:398] Monitoring the collections: metrics, losses, sm_metrics
# #015      1/Unknown - 0s 21us/step - loss: 8.4672 - v_loss: 1.1168 - p_loss: 7.3504 - v_accuracy: 0.0000e+00 - p_accuracy: 0.0000e+00#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015      6/Unknown - 0s 10ms/step - loss: 3.3733 - v_loss: 0.4924 - p_loss: 2.8809 - v_accuracy: 0.0000e+00 - p_accuracy: 0.0000e+00#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     11/Unknown - 0s 11ms/step - loss: 2.4265 - v_loss: 0.3696 - p_loss: 2.0568 - v_accuracy: 0.0000e+00 - p_accuracy: 0.0000e+00#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     16/Unknown - 0s 11ms/step - loss: 2.2679 - v_loss: 0.2747 - p_loss: 1.9932 - v_accuracy: 0.0000e+00 - p_accuracy: 0.0000e+00#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     19/Unknown - 0s 12ms/step - loss: 2.1065 - v_loss: 0.2398 - p_loss: 1.8667 - v_accuracy: 0.0000e+00 - p_accuracy: 0.0000e+00#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     22/Unknown - 0s 14ms/step - loss: 2.1771 - v_loss: 0.2578 - p_loss: 1.9193 - v_accuracy: 0.0000e+00 - p_accuracy: 0.0000e+00#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     24/Unknown - 0s 15ms/step - loss: 2.2997 - v_loss: 0.3193 - p_loss: 1.9804 - v_accuracy: 0.0000e+ ...
# _loss: 0.8953 - v_accuracy: 0.0000e+00 - p_accuracy: 0.0000e+00#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    323/Unknown - 4s 11ms/step - loss: 1.0721 - v_loss: 0.1857 - p_loss: 0.8863 - v_accuracy: 0.0000e+00 - p_accuracy: 0.0000e+00#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    328/Unknown - 4s 11ms/step - loss: 1.0664 - v_loss: 0.1830 - p_loss: 0.8834 - v_accuracy: 0.0000e+00 - p_accuracy: 0.0000e+00#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015
010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015   8544/Unknown - 95s 11ms/step - loss: 0.3129 - v_loss: 0.0155 - p_loss: 0.2974 - v_accuracy: 4.6816e-04 - p_accuracy: 0.0012#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015   8549/Unknown - 95s 11ms/step - loss: 0.3128 - v_loss: 0.0155 - p_loss: 0.2973 - v_accuracy: 4.6789e-04 - p_accuracy: 0.0012#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015   8555/Unknown - 95s 11ms/step - loss: 0.3127 - v_loss: 0.0154 - p_loss: 0.2973 - v_accuracy: 4.6756e-04 - p_accuracy: 0.0012#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015   8561/Unknown - 95s 11ms/step - loss: 0.3125 - v_loss: 0.0154 - p_loss: 0.2971 - v_accuracy: 4.6724e-04 - p_accuracy: 0.0012#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015   8567/Unknown - 95s 11ms/step - loss: 0.3126 - v_loss: 0.0154 - p_loss: 0.2972 - v_accuracy: 4.6691e-04 - p_accuracy: 0.0012#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01 ...
# #010#010#010#010#010#010#010#015   8889/Unknown - 99s 11ms/step - loss: 0.3108 - v_loss: 0.0149 - p_loss: 0.2960 - v_accuracy: 5.6249e-04 - p_accuracy: 0.0016#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015   8895/Unknown - 99s 11ms/step - loss: 0.3108 - v_loss: 0.0149 - p_loss: 0.2959 - v_accuracy: 5.6211e-04 - p_accuracy: 0.0016#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015   8901/Unknown - 99s 11ms/step - loss: 0.3108 - v_loss: 0.0149 - p_loss: 0.2960 - v_accuracy: 5.6173e-04 - p_accuracy: 0.0016#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015   8907/Unknown - 99s 11ms/step - loss: 0.3107 - v_loss: 0.0148 - p_loss: 0.2959 - v_accuracy: 5.6136e-04 - p_accuracy: 0.0016#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015   8913/Unknown - 99s 11ms/step - loss: 0.3107 - v_loss: 0.0148 - p_loss: 0.2958 - v_accuracy: 5.6098e-04 - p_accuracy: 0.0015#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015   8918/Unknown - 99s 11ms/step - loss: 0.3106 - v_loss: 0.0148 - p_loss: 0.2958 - v_accuracy: 5.6066e-04 - p_accuracy: 0.0015#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015   8924/Unknown - 99s 11ms/step - loss: 0.3106 - v_loss: 0.0148 - p_loss: 0.2958 - v_accuracy: 5.6029e-04 - p_accuracy: 0.0015#010#010#010#010#010#010#010#010#010#0 ...

# %%
from sagemaker.tuner import HyperparameterTuner,CategoricalParameter, ContinuousParameter

metric_definitions = [
    {'Name': 'loss', 'Regex': 'loss: ([0-9\\.]+)'},
    {'Name': 'v_loss', 'Regex': 'v_loss: ([0-9\\.]+)'},
    {'Name': 'p_loss', 'Regex': 'p_loss: ([0-9\\.]+)'},
    {'Name': 'v_accuracy', 'Regex': 'v_accuracy: ([0-9\\.]+)'},
    {'Name': 'p_accuracy', 'Regex': 'p_accuracy: ([0-9\\.]+)'}
]

hyperparameter_tuner = HyperparameterTuner(estimator = estimator,
                                          objective_metric_name = 'loss',
                                          objective_type = 'Minimize',
                                          max_jobs = 20,
                                          max_parallel_jobs = 10,
                                          metric_definitions=metric_definitions,
                                          hyperparameter_ranges = {
                                                'optimizer': CategoricalParameter(['adam', 'RMSprop', 'sgd']), 
                                                'learning_rate': ContinuousParameter(0.001, 0.01)
                                         })

# %%
hyperparameter_tuner.fit({'train': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/train.tfrecords',
              'validation': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords',
              'eval': 's3://sagemaker-us-east-1-322961843176/sagemaker/robot_reboot/validation.tfrecords'})
# Out:
# ...............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
